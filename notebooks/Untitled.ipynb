# %%
from py_message import send_pushover
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from py_message import send_pushover
#
# ModuleNotFoundError: No module named 'py_message'
